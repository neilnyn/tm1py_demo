# %% [markdown]
# ## Preparation
#
# imports and variables

# %%
import json
import os
import pandas as pd
import logging
import argparse
import csv
import configparser
from TM1py.Services import TM1Service
from TM1py.Objects import Dimension, Hierarchy, Element,Cube,ElementAttribute
from collections import defaultdict
from TM1py.Utils import CaseAndSpaceInsensitiveTuplesDict
import datetime

# %%
def get_tm1_service(instance_name):
    config = configparser.ConfigParser()
    config.read(r'config.ini')
    return TM1Service(**config[instance_name])

# %%
TM1_PARAMS = {
    "base_url": "https://localhost:15822",
    "user": "admin",
    "password": ""
}

# %%
TM1_CLOUD_PARAMS = {
    "base_url": "https://cubewise.planning-analytics.ibmcloud.com/tm1/api/plansamp",
    "user": "cubewise01_tm1_automation",
    "namespace": "LDAP",
    "password": "XI2b5FryLHR679",
    "ssl": True,
    "verify": True,
    "async_requests_mode": True
}

# %% [markdown]
# ## Part 1
#
# ### load data from JSON and create a dimension

# %% [markdown]
# Please open the `products.json` file in `C:/resources/` with notepad.
#
# This document describes a dimension using JSON.
#
#
#
# JSON is a popular format to exchange information between systems.
# It is commonly used in APIs as a format for data and metadata.
#
# Without TM1py it would be hard to consume for TM1

# %% [markdown]
# Now let's read the JSON file with Python.
#
# open `products.json` file with the `open` function and read it using the `json.load` function
#
# ```
# with open("file-name", "r") as file:
#     data = json.load(file)
# ```

# %% [markdown]
# Now use the `pd.json_normalize` function to turn it into a data frame

# %%
tm1 = get_tm1_service('Hello_World')
print(tm1.server.get_server_name())
# Out:
# Hello_World

# %% [markdown]
# Now connect to TM1 using
#
# ```
# tm1 = TM1Service(**TM1_PARAMS)
# ```
#
# To test the connection call below function
#
# ```
# print(tm1.server.get_server_name())
# ```
#
# Once connected successfully, use the `update_or_create_hierarchy_from_dataframe` function in the `tm1.hierarchies` module to update the `Product` dimension in TM1 based on the data frame
#
# ```
# tm1.hierarchies.update_or_create_hierarchy_from_dataframe(
#         dimension_name="dimension name",
#         hierarchy_name="hierarchy name",
#         df=df)
# ```

# %%
with open("products.json", "r") as file:
    data = json.load(file)

# %%
data
# Out:
# [{'ProductID': 'P001',
#   'ProductName': 'NextGen Tablets 1',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 851.45,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '256GB',
#    'ScreenSize': '11.6 inches',
#    'BatteryCapacity': '6000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-07-02'},
#  {'ProductID': 'P002',
#   'ProductName': 'UltraTech Smartphones 2',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'UltraTech',
#   'Price': 878.48,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '384GB',
#    'ScreenSize': '5.6 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-01-24'},
#  {'ProductID': 'P003',
#   'ProductName': 'SmartOne Smartwatches 3',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'SmartOne',
#   'Price': 525.38,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '16GB',
#    'ScreenSize': '1.5 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-03-21'},
#  {'ProductID': 'P004',
#   'ProductName': 'NextGen Smartwatches 4',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 293.36,
#   'Specifications': {'Color': 'Red',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-11-03'},
#  {'ProductID': 'P005',
#   'ProductName': 'NextGen Smartwatches 5',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 474.38,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '2.0 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-05-07'},
#  {'ProductID': 'P006',
#   'ProductName': 'MegaTech Smartwatches 6',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'MegaTech',
#   'Price': 371.89,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '1.6 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-02-10'},
#  {'ProductID': 'P007',
#   'ProductName': 'GigaMobile Tablets 7',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'GigaMobile',
#   'Price': 451.74,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '640GB',
#    'ScreenSize': '12.4 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-01-26'},
#  {'ProductID': 'P008',
#   'ProductName': 'NextGen Tablets 8',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 415.72,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '832GB',
#    'ScreenSize': '11.4 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-12-11'},
#  {'ProductID': 'P009',
#   'ProductName': 'SmartOne Smartwatches 9',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'SmartOne',
#   'Price': 353.87,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '1.8 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-06-21'},
#  {'ProductID': 'P010',
#   'ProductName': 'UltraTech Smartphones 10',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'UltraTech',
#   'Price': 285.47,
#   'Specifications': {'Color': 'White',
#    'Storage': '320GB',
#    'ScreenSize': '6.9 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-11-19'},
#  {'ProductID': 'P011',
#   'ProductName': 'NextGen Smartwatches 11',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 729.66,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-06-22'},
#  {'ProductID': 'P012',
#   'ProductName': 'TechCorp Smartwatches 12',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechCorp',
#   'Price': 792.73,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '16GB',
#    'ScreenSize': '1.8 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-08-17'},
#  {'ProductID': 'P013',
#   'ProductName': 'NextGen Smartphones 13',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'NextGen',
#   'Price': 511.99,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '384GB',
#    'ScreenSize': '6.0 inches',
#    'BatteryCapacity': '4500mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-01-03'},
#  {'ProductID': 'P014',
#   'ProductName': 'MegaTech Tablets 14',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'MegaTech',
#   'Price': 737.15,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '448GB',
#    'ScreenSize': '12.2 inches',
#    'BatteryCapacity': '6000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-08-16'},
#  {'ProductID': 'P015',
#   'ProductName': 'MegaTech Tablets 15',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'MegaTech',
#   'Price': 958.6,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '192GB',
#    'ScreenSize': '9.8 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-01-18'},
#  {'ProductID': 'P016',
#   'ProductName': 'TechWave Tablets 16',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'TechWave',
#   'Price': 785.64,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '960GB',
#    'ScreenSize': '11.4 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-08-17'},
#  {'ProductID': 'P017',
#   'ProductName': 'GigaMobile Tablets 17',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'GigaMobile',
#   'Price': 780.38,
#   'Specifications': {'Color': 'Red',
#    'Storage': '448GB',
#    'ScreenSize': '12.5 inches',
#    'BatteryCapacity': '6000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-09-19'},
#  {'ProductID': 'P018',
#   'ProductName': 'GigaMobile Smartphones 18',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'GigaMobile',
#   'Price': 973.79,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '448GB',
#    'ScreenSize': '6.3 inches',
#    'BatteryCapacity': '3500mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-05-01'},
#  {'ProductID': 'P019',
#   'ProductName': 'NextGen Smartwatches 19',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 681.7,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '16GB',
#    'ScreenSize': '1.6 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-02-16'},
#  {'ProductID': 'P020',
#   'ProductName': 'TechCorp Tablets 20',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'TechCorp',
#   'Price': 991.0,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '832GB',
#    'ScreenSize': '12.4 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-11-04'},
#  {'ProductID': 'P021',
#   'ProductName': 'GigaMobile Smartwatches 21',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'GigaMobile',
#   'Price': 639.53,
#   'Specifications': {'Color': 'Red',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-04-18'},
#  {'ProductID': 'P022',
#   'ProductName': 'MegaTech Smartwatches 22',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'MegaTech',
#   'Price': 959.93,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-03-07'},
#  {'ProductID': 'P023',
#   'ProductName': 'TechWave Tablets 23',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'TechWave',
#   'Price': 398.2,
#   'Specifications': {'Color': 'Red',
#    'Storage': '640GB',
#    'ScreenSize': '10.9 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-04-12'},
#  {'ProductID': 'P024',
#   'ProductName': 'GigaMobile Smartwatches 24',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'GigaMobile',
#   'Price': 902.19,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-07-18'},
#  {'ProductID': 'P025',
#   'ProductName': 'UltraTech Smartwatches 25',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'UltraTech',
#   'Price': 412.03,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-10-24'},
#  {'ProductID': 'P026',
#   'ProductName': 'UltraTech Smartphones 26',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'UltraTech',
#   'Price': 346.74,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '256GB',
#    'ScreenSize': '6.4 inches',
#    'BatteryCapacity': '4500mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-11-15'},
#  {'ProductID': 'P027',
#   'ProductName': 'SmartOne Smartphones 27',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'SmartOne',
#   'Price': 506.8,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '448GB',
#    'ScreenSize': '5.9 inches',
#    'BatteryCapacity': '3500mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-02-28'},
#  {'ProductID': 'P028',
#   'ProductName': 'NextGen Tablets 28',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 522.57,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '128GB',
#    'ScreenSize': '12.6 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-06-12'},
#  {'ProductID': 'P029',
#   'ProductName': 'UltraTech Smartwatches 29',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'UltraTech',
#   'Price': 466.32,
#   'Specifications': {'Color': 'Black',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-06-08'},
#  {'ProductID': 'P030',
#   'ProductName': 'UltraTech Smartwatches 30',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'UltraTech',
#   'Price': 614.0,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '16GB',
#    'ScreenSize': '1.5 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-11-09'},
#  {'ProductID': 'P031',
#   'ProductName': 'UltraTech Smartwatches 31',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'UltraTech',
#   'Price': 996.87,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '1.9 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-09-22'},
#  {'ProductID': 'P032',
#   'ProductName': 'NextGen Tablets 32',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 309.11,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '512GB',
#    'ScreenSize': '9.8 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-04-17'},
#  {'ProductID': 'P033',
#   'ProductName': 'TechWave Smartwatches 33',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechWave',
#   'Price': 939.85,
#   'Specifications': {'Color': 'Red',
#    'Storage': '16GB',
#    'ScreenSize': '1.4 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-04-15'},
#  {'ProductID': 'P034',
#   'ProductName': 'MegaTech Tablets 34',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'MegaTech',
#   'Price': 673.88,
#   'Specifications': {'Color': 'Red',
#    'Storage': '896GB',
#    'ScreenSize': '8.5 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-07-22'},
#  {'ProductID': 'P035',
#   'ProductName': 'SmartOne Smartwatches 35',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'SmartOne',
#   'Price': 507.17,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '1.9 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-01-22'},
#  {'ProductID': 'P036',
#   'ProductName': 'TechWave Smartwatches 36',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechWave',
#   'Price': 454.07,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '16GB',
#    'ScreenSize': '1.4 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-10-11'},
#  {'ProductID': 'P037',
#   'ProductName': 'GigaMobile Tablets 37',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'GigaMobile',
#   'Price': 645.13,
#   'Specifications': {'Color': 'White',
#    'Storage': '320GB',
#    'ScreenSize': '8.3 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-02-19'},
#  {'ProductID': 'P038',
#   'ProductName': 'NextGen Smartwatches 38',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 688.34,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '16GB',
#    'ScreenSize': '1.5 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-08-08'},
#  {'ProductID': 'P039',
#   'ProductName': 'NextGen Smartphones 39',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'NextGen',
#   'Price': 840.89,
#   'Specifications': {'Color': 'Black',
#    'Storage': '384GB',
#    'ScreenSize': '5.6 inches',
#    'BatteryCapacity': '3000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-11-07'},
#  {'ProductID': 'P040',
#   'ProductName': 'TechCorp Smartphones 40',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'TechCorp',
#   'Price': 622.42,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '512GB',
#    'ScreenSize': '5.7 inches',
#    'BatteryCapacity': '3500mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-10-11'},
#  {'ProductID': 'P041',
#   'ProductName': 'SmartOne Tablets 41',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'SmartOne',
#   'Price': 596.23,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '768GB',
#    'ScreenSize': '12.2 inches',
#    'BatteryCapacity': '6000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-07-14'},
#  {'ProductID': 'P042',
#   'ProductName': 'GigaMobile Tablets 42',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'GigaMobile',
#   'Price': 263.93,
#   'Specifications': {'Color': 'White',
#    'Storage': '256GB',
#    'ScreenSize': '10.0 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-10-12'},
#  {'ProductID': 'P043',
#   'ProductName': 'GigaMobile Smartwatches 43',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'GigaMobile',
#   'Price': 824.46,
#   'Specifications': {'Color': 'Red',
#    'Storage': '16GB',
#    'ScreenSize': '1.5 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-11-12'},
#  {'ProductID': 'P044',
#   'ProductName': 'TechCorp Smartphones 44',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'TechCorp',
#   'Price': 687.34,
#   'Specifications': {'Color': 'White',
#    'Storage': '192GB',
#    'ScreenSize': '6.8 inches',
#    'BatteryCapacity': '4500mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-02-23'},
#  {'ProductID': 'P045',
#   'ProductName': 'SmartOne Tablets 45',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'SmartOne',
#   'Price': 990.9,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '256GB',
#    'ScreenSize': '12.3 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-08-04'},
#  {'ProductID': 'P046',
#   'ProductName': 'TechWave Smartphones 46',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'TechWave',
#   'Price': 716.2,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '64GB',
#    'ScreenSize': '6.9 inches',
#    'BatteryCapacity': '3500mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-04-01'},
#  {'ProductID': 'P047',
#   'ProductName': 'TechCorp Smartphones 47',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'TechCorp',
#   'Price': 633.29,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '448GB',
#    'ScreenSize': '6.2 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-07-14'},
#  {'ProductID': 'P048',
#   'ProductName': 'NextGen Tablets 48',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 254.47,
#   'Specifications': {'Color': 'Red',
#    'Storage': '704GB',
#    'ScreenSize': '9.7 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-09-05'},
#  {'ProductID': 'P049',
#   'ProductName': 'GigaMobile Smartwatches 49',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'GigaMobile',
#   'Price': 745.4,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '16GB',
#    'ScreenSize': '2.0 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-05-02'},
#  {'ProductID': 'P050',
#   'ProductName': 'UltraTech Smartwatches 50',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'UltraTech',
#   'Price': 383.57,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '16GB',
#    'ScreenSize': '1.9 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-10-01'},
#  {'ProductID': 'P051',
#   'ProductName': 'MegaTech Tablets 51',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'MegaTech',
#   'Price': 548.9,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '704GB',
#    'ScreenSize': '8.5 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-02-27'},
#  {'ProductID': 'P052',
#   'ProductName': 'NextGen Tablets 52',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 816.26,
#   'Specifications': {'Color': 'Red',
#    'Storage': '320GB',
#    'ScreenSize': '10.7 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-04-07'},
#  {'ProductID': 'P053',
#   'ProductName': 'TechWave Tablets 53',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'TechWave',
#   'Price': 382.78,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '576GB',
#    'ScreenSize': '9.9 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-03-09'},
#  {'ProductID': 'P054',
#   'ProductName': 'GigaMobile Tablets 54',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'GigaMobile',
#   'Price': 856.85,
#   'Specifications': {'Color': 'White',
#    'Storage': '448GB',
#    'ScreenSize': '12.3 inches',
#    'BatteryCapacity': '6000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-06-16'},
#  {'ProductID': 'P055',
#   'ProductName': 'UltraTech Smartwatches 55',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'UltraTech',
#   'Price': 797.52,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '16GB',
#    'ScreenSize': '2.0 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-05-21'},
#  {'ProductID': 'P056',
#   'ProductName': 'MegaTech Tablets 56',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'MegaTech',
#   'Price': 924.01,
#   'Specifications': {'Color': 'Red',
#    'Storage': '896GB',
#    'ScreenSize': '12.2 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-03-26'},
#  {'ProductID': 'P057',
#   'ProductName': 'GigaMobile Smartphones 57',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'GigaMobile',
#   'Price': 326.95,
#   'Specifications': {'Color': 'White',
#    'Storage': '192GB',
#    'ScreenSize': '6.4 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-06-12'},
#  {'ProductID': 'P058',
#   'ProductName': 'GigaMobile Tablets 58',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'GigaMobile',
#   'Price': 963.19,
#   'Specifications': {'Color': 'White',
#    'Storage': '1024GB',
#    'ScreenSize': '8.3 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-03-08'},
#  {'ProductID': 'P059',
#   'ProductName': 'MegaTech Smartphones 59',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'MegaTech',
#   'Price': 373.66,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '512GB',
#    'ScreenSize': '5.9 inches',
#    'BatteryCapacity': '4000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-11-11'},
#  {'ProductID': 'P060',
#   'ProductName': 'TechCorp Tablets 60',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'TechCorp',
#   'Price': 697.95,
#   'Specifications': {'Color': 'Black',
#    'Storage': '576GB',
#    'ScreenSize': '10.8 inches',
#    'BatteryCapacity': '6000mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-01-05'},
#  {'ProductID': 'P061',
#   'ProductName': 'SmartOne Tablets 61',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'SmartOne',
#   'Price': 782.19,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '512GB',
#    'ScreenSize': '12.5 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-10-02'},
#  {'ProductID': 'P062',
#   'ProductName': 'UltraTech Smartphones 62',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'UltraTech',
#   'Price': 802.2,
#   'Specifications': {'Color': 'White',
#    'Storage': '256GB',
#    'ScreenSize': '6.1 inches',
#    'BatteryCapacity': '4500mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-04-20'},
#  {'ProductID': 'P063',
#   'ProductName': 'SmartOne Smartwatches 63',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'SmartOne',
#   'Price': 785.66,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '16GB',
#    'ScreenSize': '1.5 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-08-18'},
#  {'ProductID': 'P064',
#   'ProductName': 'TechWave Smartphones 64',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'TechWave',
#   'Price': 893.39,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '448GB',
#    'ScreenSize': '6.8 inches',
#    'BatteryCapacity': '3000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-11-20'},
#  {'ProductID': 'P065',
#   'ProductName': 'GigaMobile Smartphones 65',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'GigaMobile',
#   'Price': 804.96,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '512GB',
#    'ScreenSize': '6.1 inches',
#    'BatteryCapacity': '3500mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-12-28'},
#  {'ProductID': 'P066',
#   'ProductName': 'GigaMobile Smartwatches 66',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'GigaMobile',
#   'Price': 512.63,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '16GB',
#    'ScreenSize': '1.8 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-10-25'},
#  {'ProductID': 'P067',
#   'ProductName': 'GigaMobile Smartphones 67',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'GigaMobile',
#   'Price': 473.7,
#   'Specifications': {'Color': 'White',
#    'Storage': '128GB',
#    'ScreenSize': '5.9 inches',
#    'BatteryCapacity': '4000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-11-27'},
#  {'ProductID': 'P068',
#   'ProductName': 'NextGen Smartwatches 68',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 351.62,
#   'Specifications': {'Color': 'Red',
#    'Storage': '16GB',
#    'ScreenSize': '1.8 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-03-17'},
#  {'ProductID': 'P069',
#   'ProductName': 'NextGen Tablets 69',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 331.68,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '832GB',
#    'ScreenSize': '9.6 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-03-24'},
#  {'ProductID': 'P070',
#   'ProductName': 'MegaTech Smartwatches 70',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'MegaTech',
#   'Price': 350.57,
#   'Specifications': {'Color': 'Red',
#    'Storage': '16GB',
#    'ScreenSize': '1.8 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-10-02'},
#  {'ProductID': 'P071',
#   'ProductName': 'TechWave Tablets 71',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'TechWave',
#   'Price': 554.87,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '448GB',
#    'ScreenSize': '9.9 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-11-17'},
#  {'ProductID': 'P072',
#   'ProductName': 'TechWave Smartwatches 72',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechWave',
#   'Price': 556.6,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-04-26'},
#  {'ProductID': 'P073',
#   'ProductName': 'NextGen Smartwatches 73',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 584.28,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-02-13'},
#  {'ProductID': 'P074',
#   'ProductName': 'UltraTech Tablets 74',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'UltraTech',
#   'Price': 261.84,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '448GB',
#    'ScreenSize': '11.6 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-06-15'},
#  {'ProductID': 'P075',
#   'ProductName': 'GigaMobile Tablets 75',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'GigaMobile',
#   'Price': 580.55,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '832GB',
#    'ScreenSize': '9.3 inches',
#    'BatteryCapacity': '6000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-12-15'},
#  {'ProductID': 'P076',
#   'ProductName': 'MegaTech Smartwatches 76',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'MegaTech',
#   'Price': 288.73,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-12-07'},
#  {'ProductID': 'P077',
#   'ProductName': 'TechCorp Smartwatches 77',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechCorp',
#   'Price': 514.21,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '16GB',
#    'ScreenSize': '1.5 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-01-14'},
#  {'ProductID': 'P078',
#   'ProductName': 'TechCorp Smartwatches 78',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechCorp',
#   'Price': 749.16,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '16GB',
#    'ScreenSize': '1.9 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-07-23'},
#  {'ProductID': 'P079',
#   'ProductName': 'GigaMobile Smartphones 79',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'GigaMobile',
#   'Price': 797.67,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '384GB',
#    'ScreenSize': '5.7 inches',
#    'BatteryCapacity': '3000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-10-18'},
#  {'ProductID': 'P080',
#   'ProductName': 'UltraTech Smartphones 80',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'UltraTech',
#   'Price': 468.62,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '512GB',
#    'ScreenSize': '6.0 inches',
#    'BatteryCapacity': '3500mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-09-09'},
#  {'ProductID': 'P081',
#   'ProductName': 'SmartOne Smartwatches 81',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'SmartOne',
#   'Price': 471.69,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '16GB',
#    'ScreenSize': '1.6 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-04-01'},
#  {'ProductID': 'P082',
#   'ProductName': 'UltraTech Smartwatches 82',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'UltraTech',
#   'Price': 418.82,
#   'Specifications': {'Color': 'Red',
#    'Storage': '16GB',
#    'ScreenSize': '1.5 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-01-17'},
#  {'ProductID': 'P083',
#   'ProductName': 'UltraTech Smartwatches 83',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'UltraTech',
#   'Price': 667.51,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '16GB',
#    'ScreenSize': '2.0 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-07-21'},
#  {'ProductID': 'P084',
#   'ProductName': 'TechWave Smartphones 84',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'TechWave',
#   'Price': 567.2,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '512GB',
#    'ScreenSize': '6.7 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-12-24'},
#  {'ProductID': 'P085',
#   'ProductName': 'NextGen Tablets 85',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 684.13,
#   'Specifications': {'Color': 'Red',
#    'Storage': '512GB',
#    'ScreenSize': '10.1 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-10-27'},
#  {'ProductID': 'P086',
#   'ProductName': 'MegaTech Tablets 86',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'MegaTech',
#   'Price': 805.3,
#   'Specifications': {'Color': 'Black',
#    'Storage': '448GB',
#    'ScreenSize': '10.9 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-09-12'},
#  {'ProductID': 'P087',
#   'ProductName': 'TechWave Smartwatches 87',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechWave',
#   'Price': 426.79,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '16GB',
#    'ScreenSize': '1.7 inches',
#    'BatteryCapacity': '350mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-02-08'},
#  {'ProductID': 'P088',
#   'ProductName': 'MegaTech Smartwatches 88',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'MegaTech',
#   'Price': 660.02,
#   'Specifications': {'Color': 'Black',
#    'Storage': '16GB',
#    'ScreenSize': '1.6 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-02-12'},
#  {'ProductID': 'P089',
#   'ProductName': 'SmartOne Smartwatches 89',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'SmartOne',
#   'Price': 584.53,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '16GB',
#    'ScreenSize': '1.5 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-04-14'},
#  {'ProductID': 'P090',
#   'ProductName': 'NextGen Tablets 90',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'NextGen',
#   'Price': 397.39,
#   'Specifications': {'Color': 'White',
#    'Storage': '960GB',
#    'ScreenSize': '11.9 inches',
#    'BatteryCapacity': '7000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-09-06'},
#  {'ProductID': 'P091',
#   'ProductName': 'NextGen Smartphones 91',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'NextGen',
#   'Price': 939.19,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '512GB',
#    'ScreenSize': '6.0 inches',
#    'BatteryCapacity': '3500mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 2x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-11-20'},
#  {'ProductID': 'P092',
#   'ProductName': 'TechWave Smartwatches 92',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechWave',
#   'Price': 457.78,
#   'Specifications': {'Color': 'Red',
#    'Storage': '16GB',
#    'ScreenSize': '1.6 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-08-14'},
#  {'ProductID': 'P093',
#   'ProductName': 'NextGen Smartwatches 93',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 683.17,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '16GB',
#    'ScreenSize': '1.9 inches',
#    'BatteryCapacity': '280mAh'},
#   'Features': {'Camera': {'Resolution': '20MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-09-22'},
#  {'ProductID': 'P094',
#   'ProductName': 'TechCorp Smartwatches 94',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'TechCorp',
#   'Price': 912.75,
#   'Specifications': {'Color': 'White',
#    'Storage': '16GB',
#    'ScreenSize': '1.9 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-11-14'},
#  {'ProductID': 'P095',
#   'ProductName': 'SmartOne Tablets 95',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'SmartOne',
#   'Price': 793.45,
#   'Specifications': {'Color': 'Gray',
#    'Storage': '320GB',
#    'ScreenSize': '10.5 inches',
#    'BatteryCapacity': '8000mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 5'}},
#   'ReleaseDate': '2023-06-18'},
#  {'ProductID': 'P096',
#   'ProductName': 'SmartOne Smartphones 96',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'SmartOne',
#   'Price': 900.31,
#   'Specifications': {'Color': 'Gold',
#    'Storage': '192GB',
#    'ScreenSize': '6.1 inches',
#    'BatteryCapacity': '4000mAh'},
#   'Features': {'Camera': {'Resolution': '8MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-04-14'},
#  {'ProductID': 'P097',
#   'ProductName': 'TechCorp Smartphones 97',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'TechCorp',
#   'Price': 560.22,
#   'Specifications': {'Color': 'Black',
#    'Storage': '384GB',
#    'ScreenSize': '5.8 inches',
#    'BatteryCapacity': '3500mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 5x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-09-13'},
#  {'ProductID': 'P098',
#   'ProductName': 'NextGen Smartwatches 98',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Wearable Devices',
#    'ProductType': 'Smartwatches'},
#   'Brand': 'NextGen',
#   'Price': 911.61,
#   'Specifications': {'Color': 'Blue',
#    'Storage': '16GB',
#    'ScreenSize': '1.6 inches',
#    'BatteryCapacity': '300mAh'},
#   'Features': {'Camera': {'Resolution': '16MP', 'Zoom': 'Optical 4x'},
#    'Connectivity': {'Type': 'Bluetooth', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-04-20'},
#  {'ProductID': 'P099',
#   'ProductName': 'NextGen Smartphones 99',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Smartphones'},
#   'Brand': 'NextGen',
#   'Price': 676.95,
#   'Specifications': {'Color': 'Silver',
#    'Storage': '64GB',
#    'ScreenSize': '5.8 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 3x'},
#    'Connectivity': {'Type': '5G', 'WiFi': 'WiFi 4'}},
#   'ReleaseDate': '2023-10-27'},
#  {'ProductID': 'P100',
#   'ProductName': 'TechWave Tablets 100',
#   'Category': {'MainCategory': 'Electronics',
#    'SubCategory': 'Mobile Devices',
#    'ProductType': 'Tablets'},
#   'Brand': 'TechWave',
#   'Price': 915.13,
#   'Specifications': {'Color': 'White',
#    'Storage': '576GB',
#    'ScreenSize': '9.1 inches',
#    'BatteryCapacity': '5000mAh'},
#   'Features': {'Camera': {'Resolution': '12MP', 'Zoom': 'Optical 6x'},
#    'Connectivity': {'Type': '4G LTE', 'WiFi': 'WiFi 6'}},
#   'ReleaseDate': '2023-10-02'}]

# %%
df = pd.DataFrame(data=data)

# %%
df
# Out:
#    ProductID              ProductName  \
# 0       P001        NextGen Tablets 1
# 1       P002  UltraTech Smartphones 2
# 2       P003  SmartOne Smartwatches 3
# 3       P004   NextGen Smartwatches 4
# 4       P005   NextGen Smartwatches 5
# ..       ...                      ...
# 95      P096  SmartOne Smartphones 96
# 96      P097  TechCorp Smartphones 97
# 97      P098  NextGen Smartwatches 98
# 98      P099   NextGen Smartphones 99
# 99      P100     TechWave Tablets 100
#
#                                              Category      Brand   Price  \
# 0   {'MainCategory': 'Electronics', 'SubCategory':...    NextGen  851.45
# 1   {'MainCategory': 'Electronics', 'SubCategory':...  UltraTech  878.48
# 2   {'MainCategory': 'Electronics', 'SubCategory':...   SmartOne  525.38
# 3   {'MainCategory': 'Electronics', 'SubCategory':...    NextGen  293.36
# 4   {'MainCategory': 'Electronics', 'SubCategory':...    NextGen  474.38
# ..                                                ...        ...     ...
# 95  {'MainCategory': 'Electronics', 'SubCategory':...   SmartOne  900.31
# 96  {'MainCategory': 'Electronics', 'SubCategory':...   TechCorp  560.22
# 97  {'MainCategory': 'Electronics', 'SubCategory':...    NextGen  911.61
# 98  {'MainCategory': 'Electronics', 'SubCategory':...    NextGen  676.95
# 99  {'MainCategory': 'Electronics', 'SubCategory':...   TechWave  915.13
#
#                                        Specifications  \
# 0   {'Color': 'Gold', 'Storage': '256GB', 'ScreenS...
# 1   {'Color': 'Blue', 'Storage': '384GB', 'ScreenS...
# 2   {'Color': 'Blue', 'Storage': '16GB', 'ScreenSi...
# 3   {'Color': 'Red', 'Storage': '16GB', 'ScreenSiz...
# 4   {'Color': 'White', 'Storage': '16GB', 'ScreenS...
# ..                                                ...
# 95  {'Color': 'Gold', 'Storage': '192GB', 'ScreenS...
# 96  {'Color': 'Black', 'Storage': '384GB', 'Screen...
# 97  {'Color': 'Blue', 'Storage': '16GB', 'ScreenSi...
# 98  {'Color': 'Silver', 'Storage': '64GB', 'Screen...
# 99  {'Color': 'White', 'Storage': '576GB', 'Screen...
#
#                                              Features ReleaseDate
# 0   {'Camera': {'Resolution': '20MP', 'Zoom': 'Opt...  2023-07-02
# 1   {'Camera': {'Resolution': '8MP', 'Zoom': 'Opti...  2023-01-24
# 2   {'Camera': {'Resolution': '12MP', 'Zoom': 'Opt...  2023-03-21
# 3   {'Camera': {'Resolution': '8MP', 'Zoom': 'Opti...  2023-11-03
# 4   {'Camera': {'Resolution': '12MP', 'Zoom': 'Opt...  2023-05-07
# ..                                                ...         ...
# 95  {'Camera': {'Resolution': '8MP', 'Zoom': 'Opti...  2023-04-14
# 96  {'Camera': {'Resolution': '12MP', 'Zoom': 'Opt...  2023-09-13
# 97  {'Camera': {'Resolution': '16MP', 'Zoom': 'Opt...  2023-04-20
# 98  {'Camera': {'Resolution': '12MP', 'Zoom': 'Opt...  2023-10-27
# 99  {'Camera': {'Resolution': '12MP', 'Zoom': 'Opt...  2023-10-02
#
# [100 rows x 8 columns]

# %% [markdown]
# Please review the result in TM1
#
# The dimension should be complete, but there are no hierarchies or consolidations in it yet!
#
# We can manipulate the data frame and add special level columns to it. Then TM1py will create the hierarchy accordingly.
#
# To make sure each product has `Level000` as a root parent you can write this:
#
# ```
# df["Level000"] = "All Products"
# ```
#
# We can use the existing columns `"Category.ProductType"`, `"Category.SubCategory"` , `"Category.MainCategory"` in the data frame to define a good hierarchy.
#
# Please create 3 new columns in the dataframe based on the existing 3 columns mentioned above, like this:
#
# ```
# df["Level001"] = df["existing column"]
# df["Level002"] = df["existing column"]
# df["Level003"] = df["existing column"]
# ```
#
# Make sure the order is sensible. You can always print out your dataframe to view it as a table

# %% [markdown]
# Now use the `update_or_create_hierarchy_from_dataframe` function in the `tm1.hierarchies` module to update the `Product` dimension in TM1 again
#
# ```
# tm1.hierarchies.update_or_create_hierarchy_from_dataframe(
#         dimension_name="dimension name",
#         hierarchy_name="hierarchy name",
#         df=df,
#         unwind=True)
# ```
#
# You can pass `unwind=True` to unwind/break all existing consolidation in the dimension

# %% [markdown]
# -----

# %% [markdown]
# ## Part 2
#
# ### load data from JSON and write to cube

# %% [markdown]
# open `sales.json` file and read it using the `json` module
#
# ```
# with open("file-name", "r") as file:
#     data = json.load(file)
# ```

# %% [markdown]
# Now use the `pd.json_normalize` function to turn it into a data frame
#
# Once it is a dataframe you can call `df.shape()` or `df.sample(5)` to get an overview of the data

# %% [markdown]
# Before we can write the dataframe to our Sales cube in TM1, we need to make sure the data has the right granularity and the columns are in the right order.
#
# Please add a column to the dataframe for the Version and assign all records to "Actual"
# You can use this syntax
#
# ```
# df["Column"] = "Value"
# ```
#
#
# Please also order the columns according to the dimension in the cube
#
# ```
# df = df[["Month", "Version", "Region", ..., "Value"]]
# ```

# %% [markdown]
# The data frame should looks like this
#
# |        | Month   | Version   | Region      | Customer          | ProductID   | SalesChannel   | Measure        |   Value |
# |-------:|:--------|:----------|:------------|:------------------|:------------|:---------------|:---------------|--------:|
# |  24811 | 2022-03 | Actual    | Italy       | Jackson Corp      | P005        | Wholesale      | Sales Quantity |     486 |
# |  91695 | 2023-03 | Actual    | Russia      | Garcia Devices    | P067        | Retail         | Sales Quantity |     456 |
# |   1106 | 2023-12 | Actual    | New Zealand | Williams Tech     | P060        | Retail         | Sales Quantity |     172 |
#
#
# Now you can use the `write_dataframe` function in the `tm1.cells` module to write to the Sales cube with below syntax
#
# ```
# tm1.cells.write_dataframe(cube_name="cube name", data=df, use_blob=True)
# ```
#
# Make sure to pass `use_blob=True` as this speeds up the operation

# %% [markdown]
# -----

# %% [markdown]
# ## Part 3: The Challenge
#
# ### Synchronize local TM1 with cloud TM1 instance

# %% [markdown]
# In the top of this notebook you find a variable called `TM1_CLOUD_PARAMS`.
# Please first verify that you can connect to this instance with TM1py.
#
# In Part 3 you need to write the 2023 actuals from the local Sales cube to a budget version in an aggregated cube in the cloud for 2024 with a 10% increase on each value.

# %% [markdown]
# **Step 1**: extract 2023 actual data from Sales cube to a data frame, using MDX
#
# hint: use Arc to generate the MDX
#
# hint: use the `tm1.cells.execute_mdx_dataframe` function to run the MDX and get a dataframe

# %% [markdown]
# **Step 2**: increase the values by 10%
#
# hint: `df["column name"] = df["column name"] * 1.1`

# %% [markdown]
# **Step3**: change the value in the version column from `"actual"` to `"Budget your-name"`

# %% [markdown]
# **Step4**: change all periods from 2023 to 2024
#
# hint: `df["column name"] = df["column name"].str.replace("old value", "new value")`

# %% [markdown]
# **Step5**: Before you write, make sure to crate the new budget element in the version dimension.
#
# hint:
#
# ```
#     from TM1py import Element
#     new_version_element = "Budget Marius"
#
#     if tm1_cloud.elements.exists(dimension_name="Version", hierarchy_name="Version", element_name=new_version_element):
#         tm1_cloud.elements.create("Version", "Version", element=Element(new_version_element, "Numeric"))
# ```

# %% [markdown]
# **Step6**: write the dataframe to the Sales cube in the TM1 cloud instance
#
# make sure the column order is in line with the cube dimension order

# %% [markdown]
# -----

# %% [markdown]
# ## Part 4: Optional
#
# - Create product attributes with their correct type (e.g., `Product Name` shoud be Alias). _Hint: checkout the docs on the `update_or_create_hierarchy_from_dataframe` function_
#
# - Clear a slice in the `Sales` cube before the write operation. _hint: use bedrock or tm1py's clear_with_mdx function_
#
# - In the cloud instance you find another cube: `Sales Summary`. This cube has all the same dimensions as `Sales` except for `Customer`. Please read a new slice from your source cube, using MDX, with the aggregated values for `All Customers` and write the data to `Sales Summary` in the cloud instance
#
# - Make sure the `product` dimension is sync between the two instances! Use the `get_elements_dataframe` function in `tm1.elements` to retrieve the dimension as a dataframe from the source instance. Use the `update_or_create_hierarchy_from_dataframe` function in `tm1.hierarchies` to update the Product dimension in the target TM1 instance
