# %% [markdown]
# ### 连localhost sql server

# %%
import pymssql

# %%
conn=pymssql.connect(server='192.168.1.118',user='sa',password='123456',database='ZL_STG')

# %%
import pandas as pd
sql='SELECT * FROM [ZL_STG].[dbo].[ZL_STG_Amazon_Payments_2018_quan]'
df0=pd.read_sql(sql,conn)
df=pd.DataFrame(df0)

# %% [markdown]
# ### 连远程sql server

# %%
import pymssql

# %%
conn=pymssql.connect(server='192.168.1.156',user='sa',password='Sa123456',database='ZL_Payments_Data')
sql='SELECT Top 1000000 * FROM [ZL_Payments_Data].[dbo].[ZL_STG_Amazon_Payments_2018_to_2021_quan]'
df0=pd.read_sql(sql,conn)
df=pd.DataFrame(df0)

# %%
df
# Out:
#                website currency behavior            date_time  ... other_transaction_fees other   total diff_amount
# 0        201906月__us3站      USD     商品销售  2019-06-19 19:49:40  ...                      0     0   12.58           0
# 1        201906月__us3站      USD     商品销售  2019-06-19 19:52:01  ...                      0     0   14.28           0
# 2        201906月__us3站      USD     商品销售  2019-06-19 19:52:18  ...                      0     0   17.39           0
# 3        201906月__us3站      USD     商品销售  2019-06-19 19:52:28  ...                      0     0   21.82           0
# 4        201906月__us3站      USD     商品销售  2019-06-19 19:58:10  ...                      0     0    9.68           0
# ...                ...      ...      ...                  ...  ...                    ...   ...     ...         ...
# 999995  202112月__us07站      USD     销售退款  2021-12-07 20:00:59  ...                      0     0  -18.29           0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   website                      1000000 non-null  object
#  1   currency                     1000000 non-null  object
#  2   behavior                     1000000 non-null  object
#  3   date_time                    1000000 non-null  object
#  4   settlement_id                1000000 non-null  object
#  5   type                         965539 non-null   object
#  6   order_id                     991721 non-null   object
#  7   sku                          949754 non-null   object
#  8   description                  999977 non-null   object
#  9   quantity                     989562 non-null   float64
#  10  marketplace                  986246 non-null   object
#  11  account_type                 465728 non-null   object
# ...

# %%
df['product_sales']=df['product_sales'].astype('float')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000000 entries, 0 to 999999
# Data columns (total 36 columns):
#  #   Column                       Non-Null Count    Dtype
# ---  ------                       --------------    -----
#  0   website                      1000000 non-null  object
#  1   currency                     1000000 non-null  object
#  2   behavior                     1000000 non-null  object
#  3   date_time                    1000000 non-null  object
#  4   settlement_id                1000000 non-null  object
#  5   type                         965539 non-null   object
#  6   order_id                     991721 non-null   object
#  7   sku                          949754 non-null   object
#  8   description                  999977 non-null   object
#  9   quantity                     989562 non-null   float64
#  10  marketplace                  986246 non-null   object
#  11  account_type                 465728 non-null   object
# ...

# %%
df_group=df.groupby(by='marketplace')

# %%
df_group.sum()[['product_sales']]
# Out:
#                                            product_sales
# marketplace
#                                                     0.00
# 0                                                   0.00
# Amazon.ca                                           0.00
# Amazon.co.jp                                        0.00
# Amazon.co.uk                                  1314780.47
# Amazon.com                                    8459631.19
# Amazon.com.mx                                       0.00
# Amazon.de                                      570951.90
# Amazon.es                                           0.00
# Amazon.fr                                      179881.30
# Amazon.it                                           0.00
# amazon.ca                                      107292.02
# amazon.co.uk                                  1199988.46
# amazon.com                                    5926771.12
# amazon.com.mx                                  214818.98
# ...
