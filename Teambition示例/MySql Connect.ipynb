# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# 初始化数据库连接
# 按实际情况依次填写MySQL的用户名、密码、IP地址、端口、数据库名

engine = create_engine("mysql+pymysql://{}:{}@{}:{}/{}".format('root', '1234', 
                                                               'localhost', '3306', 'pa'))

# %%
# MySQL导入DataFrame
# 填写自己所需的SQL语句，可以是复杂的查询语句
#zl_stg_amazon_payments_2018_to_2021_quan
sql_query = 'select * from pa.exchange_rate'
# 使用pandas的read_sql_query函数执行SQL语句，并存入DataFrame
df_read = pd.read_sql_query(sql_query, engine)

# %%
df_read
# Out:
#     Scenario SA_Year SA_Month Version Currency_From Currency_To  \
# 0        ACT    2021      M11     WIP           USD         USD
# 1        ACT    2021      M11     WIP           USD         USD
# 2        ACT    2021      M11     WIP           USD         USD
# 3        ACT    2021      M11     WIP           USD         GBP
# 4        ACT    2021      M11     WIP           USD         GBP
# ..       ...     ...      ...     ...           ...         ...
# 721      ACT    2021      M12     WIP           TRY         CNY
# 722      ACT    2021      M12     WIP           TRY         CNY
# 723      ACT    2021      M12     WIP           TRY         TRY
# 724      ACT    2021      M12     WIP           TRY         TRY
# 725      ACT    2021      M12     WIP           TRY         TRY
#
#     M_Exchange_Rate              sValue
# 0          BOM Rate                   1
# 1          EOM Rate                   1
# 2      Average Rate                   1
# ...

# %%
import pandas as pd
import pymysql
from sqlalchemy import create_engine

# 初始化数据库连接
# 按实际情况依次填写MySQL的用户名、密码、IP地址、端口、数据库名

engine = create_engine("mysql+pymysql://{}:{}@{}:{}/{}".format('root', '123', 
                                                               'localhost', '3306', 'mysql'))

# %%
engine
# Out:
# Engine(mysql+pymysql://root:***@localhost:3306/mysql)

# %%
sql_query = 'select * from user'
# 使用pandas的read_sql_query函数执行SQL语句，并存入DataFrame
df_read = pd.read_sql_query(sql_query, engine)

# %%
df_read
# Out:
#         Host           User Select_priv Insert_priv Update_priv Delete_priv  \
# 0  localhost           root           Y           Y           Y           Y
# 1  localhost  mysql.session           N           N           N           N
# 2  localhost      mysql.sys           N           N           N           N
#
#   Create_priv Drop_priv Reload_priv Shutdown_priv  ... max_questions  \
# 0           Y         Y           Y             Y  ...             0
# 1           N         N           N             N  ...             0
# 2           N         N           N             N  ...             0
#
#   max_updates max_connections max_user_connections                 plugin  \
# 0           0               0                    0  mysql_native_password
# 1           0               0                    0  mysql_native_password
# 2           0               0                    0  mysql_native_password
#
#                        authentication_string password_expired  \
# ...
