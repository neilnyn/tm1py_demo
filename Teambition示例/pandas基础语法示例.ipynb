# %%
import pandas as pd

# %%
df=pd.DataFrame({'A':[1,2,3],'B':[3,4,5]})

# %% [markdown]
# #### DataFrame

# %%
df
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  3  5

# %% [markdown]
# #### DataSeries

# %%
Se=pd.Series([1,2,3])

# %%
Se
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %% [markdown]
# #### 导入数据

# %%
df=pd.read_csv(r'C:\数据练习\4使用Python进行Excel数据处理\salaries.csv')

# %%
df
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle    BasePay  \
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18
# 1                      CAPTAIN III (POLICE DEPARTMENT)  155966.02
# 2                      CAPTAIN III (POLICE DEPARTMENT)  212739.13
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60
# ...                                                ...        ...
# 148649                                       Custodian       0.00
# ...

# %%
df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
df.shape
# Out:
# (148654, 13)

# %%
df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
df[['EmployeeName']]
# Out:
#              EmployeeName
# 0          NATHANIEL FORD
# 1            GARY JIMENEZ
# 2          ALBERT PARDINI
# 3       CHRISTOPHER CHONG
# 4         PATRICK GARDNER
# ...                   ...
# 148649      Roy I Tillery
# 148650       Not provided
# 148651       Not provided
# 148652       Not provided
# 148653          Joe Lopez
#
# [148654 rows x 1 columns]

# %%
df[['Id','EmployeeName','BasePay']]
# Out:
#             Id       EmployeeName    BasePay
# 0            1     NATHANIEL FORD  167411.18
# 1            2       GARY JIMENEZ  155966.02
# 2            3     ALBERT PARDINI  212739.13
# 3            4  CHRISTOPHER CHONG   77916.00
# 4            5    PATRICK GARDNER  134401.60
# ...        ...                ...        ...
# 148649  148650      Roy I Tillery       0.00
# 148650  148651       Not provided        NaN
# 148651  148652       Not provided        NaN
# 148652  148653       Not provided        NaN
# 148653  148654          Joe Lopez       0.00
#
# [148654 rows x 3 columns]

# %%
df[df['Year']==2011]
# Out:
#           Id        EmployeeName  \
# 0          1      NATHANIEL FORD
# 1          2        GARY JIMENEZ
# 2          3      ALBERT PARDINI
# 3          4   CHRISTOPHER CHONG
# 4          5     PATRICK GARDNER
# ...      ...                 ...
# 36154  36155       SERENA HUGHES
# 36155  36156        JOE BROWN JR
# 36156  36157      PAULETTE ADAMS
# 36157  36158       KAUKAB MOHSIN
# 36158  36159  JOSEPHINE MCCREARY
#
#                                              JobTitle    BasePay  OvertimePay  \
# 0      GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY  167411.18         0.00
# 1                     CAPTAIN III (POLICE DEPARTMENT)  155966.02    245131.88
# 2                     CAPTAIN III (POLICE DEPARTMENT)  212739.13    106088.18
# 3                WIRE ROPE CABLE MAINTENANCE MECHANIC   77916.00     56120.71
# 4        DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)  134401.60      9737.00
# ...                                               ...        ...          ...
# ...

# %%
df[df['BasePay']>200000]
# Out:
#             Id        EmployeeName                                JobTitle  \
# 2            3      ALBERT PARDINI         CAPTAIN III (POLICE DEPARTMENT)
# 7            8       DAVID KUSHNER          DEPUTY DIRECTOR OF INVESTMENTS
# 9           10  JOANNE HAYES-WHITE  CHIEF OF DEPARTMENT, (FIRE DEPARTMENT)
# 12          13   EDWARD HARRINGTON             EXECUTIVE CONTRACT EMPLOYEE
# 13          14         JOHN MARTIN                       DEPARTMENT HEAD V
# ...        ...                 ...                                     ...
# 110953  110954      Ronald P Flynn              Assistant Chief Attorney 1
# 110954  110955    Sheryl L Bregman              Assistant Chief Attorney 1
# 110976  110977       Susan T Obata              Supervising Physician Spec
# 110977  110978       John O Funghi            Engineer/Architect Principal
# 111107  111108       Mayra T Vivas             Senior Physician Specialist
#
#           BasePay  OvertimePay  OtherPay  Benefits   TotalPay  \
# ...

# %%
df[(df['BasePay']>250000) & (df['Year']==2012)]
# Out:
#           Id         EmployeeName                     JobTitle    BasePay  \
# 36160  36161         Gregory Suhr              Chief of Police  302578.00
# 36162  36163   Joanne Hayes-White       Chief, Fire Department  296943.01
# 36164  36165             Amy Hart                  Dept Head V  271607.74
# 36165  36166       Edward Reiskin   Gen Mgr, Public Trnsp Dept  294000.17
# 36166  36167          John Martin                  Dept Head V  287747.89
# 36175  36176        Ellen Moffatt            Asst Med Examiner  260528.26
# 36178  36179         Judy Melinek            Asst Med Examiner  260528.15
# 36181  36182         James Dudley               Deputy Chief 3  263426.50
# 36182  36183        Mark Gonzales  Dep Chf of Dept (Fire Dept)  252423.60
# 36185  36186         Trent Rhorer                  Dept Head V  253649.80
# 36187  36188       Barbara Garcia                  Dept Head V  253435.69
# 36188  36189         Susan Currin     Adm, SFGH Medical Center  254878.82
# ...

# %%
df.loc[[0,2,4]]
# Out:
#    Id     EmployeeName                                        JobTitle  \
# 0   1   NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 2   3   ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4   5  PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN
# 4  2011    NaN  San Francisco     NaN

# %%
df.loc[[0,2,4],'EmployeeName']
# Out:
# 0     NATHANIEL FORD
# 2     ALBERT PARDINI
# 4    PATRICK GARDNER
# Name: EmployeeName, dtype: object

# %%
df.loc[[0,2,4],['EmployeeName','BasePay']]
# Out:
#       EmployeeName    BasePay
# 0   NATHANIEL FORD  167411.18
# 2   ALBERT PARDINI  212739.13
# 4  PATRICK GARDNER  134401.60

# %%
df.loc[:,'EmployeeName':'Year']
# Out:
#              EmployeeName                                        JobTitle  \
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3       CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                   ...                                             ...
# 148649      Roy I Tillery                                       Custodian
# 148650       Not provided                                    Not provided
# 148651       Not provided                                    Not provided
# 148652       Not provided                                    Not provided
# 148653          Joe Lopez                      Counselor, Log Cabin Ranch
#
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# ...

# %%
df.iloc[:,0:3]
# Out:
#             Id       EmployeeName  \
# 0            1     NATHANIEL FORD
# 1            2       GARY JIMENEZ
# 2            3     ALBERT PARDINI
# 3            4  CHRISTOPHER CHONG
# 4            5    PATRICK GARDNER
# ...        ...                ...
# 148649  148650      Roy I Tillery
# 148650  148651       Not provided
# 148651  148652       Not provided
# 148652  148653       Not provided
# 148653  148654          Joe Lopez
#
#                                               JobTitle
# 0       GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1                      CAPTAIN III (POLICE DEPARTMENT)
# 2                      CAPTAIN III (POLICE DEPARTMENT)
# 3                 WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4         DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# ...                                                ...
# 148649                                       Custodian
# 148650                                    Not provided
# ...

# %%
df.iloc[0:2,0:3]
# Out:
#    Id    EmployeeName                                        JobTitle
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)

# %%
data1=df.iloc[0:1,:]

# %%
data2=df.iloc[1:2,:]

# %%
data3=df.iloc[2:3,:]

# %%
pd.concat([data1,data2,data3])
# Out:
#    Id    EmployeeName                                        JobTitle  \
# 0   1  NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2    GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3  ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
#
#    Year  Notes         Agency  Status
# 0  2011    NaN  San Francisco     NaN
# 1  2011    NaN  San Francisco     NaN
# 2  2011    NaN  San Francisco     NaN

# %%
excel_file=pd.concat([data1,data2,data3])
excel_file.to_excel(r'C:\Users\User\Desktop\Test.xlsx',sheet_name='Test_data')
csv_file.to_csv(r'C:\Users\User\Desktop\Test.csv')

# %%
df_exp=pd.DataFrame({"姓名":['Apple','Neo','Jojo'],"性别":['女','男','男']})

# %%
df_exp
# Out:
#       姓名 性别
# 0  Apple  女
# 1    Neo  男
# 2   Jojo  男

# %%
df_exp['年龄']=['21','22','23']
df_exp
# Out:
#       姓名 性别  年龄
# 0  Apple  女  21
# 1    Neo  男  22
# 2   Jojo  男  23

# %%
df_exp.drop('年龄',axis=1)
# Out:
#       姓名 性别
# 0  Apple  女
# 1    Neo  男
# 2   Jojo  男

# %%
df_exp.drop(1,axis=0)
# Out:
#       姓名 性别  年龄
# 0  Apple  女  21
# 2   Jojo  男  23

# %%
df_exp.columns=['Name','Sex','Age']

# %%
df_exp
# Out:
#     Name Sex Age
# 0  Apple   女  21
# 1    Neo   男  22
# 2   Jojo   男  23

# %%
df_exp.reindex(columns=['Age','Sex','Name'])
# Out:
#   Age Sex   Name
# 0  21   女  Apple
# 1  22   男    Neo
# 2  23   男   Jojo

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df['Year'].nunique()
# Out:
# 4

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df[df['BasePay']==df['BasePay'].max()]['EmployeeName']
# Out:
# 72925    Gregory P Suhr
# Name: EmployeeName, dtype: object

# %%
df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
df.groupby('Year')

# %%
df.groupby('Year').mean()
# Out:
#             Id       BasePay  OvertimePay     OtherPay      Benefits  \
# Year
# 2011   18080.0  63595.956517  4531.065429  3617.081926           NaN
# 2012   54542.5  65436.406857  5023.417824  3653.437583  26439.966967
# 2013   91728.5  69630.030216  5281.641980  3819.969007  23829.076572
# 2014  129593.0  66564.421924  5401.993737  3505.421251  24789.601756
#
#           TotalPay  TotalPayBenefits  Notes  Status
# Year
# 2011  71744.103871      71744.103871    NaN     NaN
# 2012  74113.262265     100553.229232    NaN     NaN
# 2013  77611.443142     101440.519714    NaN     NaN
# 2014  75463.918140     100250.918884    NaN     NaN

# %%
df[['BasePay']].sort_values(by='BasePay',ascending=False)
# Out:
#           BasePay
# 72925   319275.01
# 110532  318835.49
# 72929   315572.01
# 72926   313686.01
# 72931   313312.52
# ...           ...
# 110530        NaN
# 148646        NaN
# 148650        NaN
# 148651        NaN
# 148652        NaN
#
# [148654 rows x 1 columns]
